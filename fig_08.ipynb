# %% [markdown]
# # Preamble

# %%
import matplotlib.pylab as plt
import matplotlib.gridspec as gridspec
import xarray as xr
import numpy as np
import re

# %%
def derivatives(new_grid, unmasked_unvalid_input_data):
    vxyz = xr.concat([new_grid.cartesian_x_vertices, new_grid.cartesian_y_vertices, new_grid.cartesian_z_vertices], dim="xyz")
    cxyz = xr.concat([new_grid.cell_circumcenter_cartesian_x, new_grid.cell_circumcenter_cartesian_y, new_grid.cell_circumcenter_cartesian_z], dim="xyz")

    def norm(da, dim):
        axis = da.dims.index(dim)
        resulting_dims = tuple(d for d in da.dims if d != dim)
        return xr.DataArray(np.linalg.norm(da.values, axis=axis), dims=resulting_dims)

    def normalize(da, dim):
        return da / norm(da, dim)

    north      = xr.DataArray([0., 0., 1.], dims=("xyz",))
    cell_up    = cxyz
    cell_east  = normalize(xr.cross(north, cell_up, dim="xyz"), "xyz")
    cell_north = normalize(xr.cross(cell_up, cell_east, dim="xyz"), "xyz")

    local_orientation = xr.concat([cell_east, cell_north, cell_up], dim="enu")

    neighbors_mask  = (new_grid.neighbor_cell_index.T - 1)
    valid_mask      = np.all(neighbors_mask>=0, axis=-1)
    
    dxyz       = (cxyz.drop_vars("cell").isel(cell=neighbors_mask[valid_mask]) - cxyz[:,valid_mask]) * new_grid.attrs["sphere_radius"]
    denu       = xr.dot(local_orientation[:,:,valid_mask], dxyz, dims="xyz")

    de, dn, du = denu.transpose("enu", "cell", "nv").values
    ones       = np.ones_like(de)
    A          = np.stack((ones, de, dn), axis=-1)  # cells, neighbors, oll
    A_inv      = np.linalg.inv(A)
    
    print('A_inv.shape:', A_inv.shape)
    varibale_0, dvariable_dx, dvariable_dy = np.einsum('...ij,...j->i...', A_inv, unmasked_unvalid_input_data[...,neighbors_mask[valid_mask]])
    
    return varibale_0, dvariable_dx, dvariable_dy, valid_mask

# %%
def zonal_mean_2nd_derivative(variable, new_grid, bins):
    counts_per_bin, lat_bins = np.histogram(new_grid.clat, bins=bins)
    varsum_per_bin, _ = np.histogram(new_grid.clat, weights=variable, bins=bins)
    zonal_mean = varsum_per_bin / counts_per_bin
    return zonal_mean, lat_bins

# %%
def dpdz(p, z, g, R, SST, c_p, H0):
    return -(p * g) / (R * ( SST - 0.5 - (g*z)/c_p) )

# Composite trapezoidal rule for numerical integration
def trapezoidal_rule(p_initial, z_values, dz, g, R_values, SST, c_p, H0):
    p_values = [p_initial]

    for i in range(1, len(z_values)):
        # Update the temperature and R_d for each integration step
        z_current = z_values[i - 1]
        R_current = R_values[i - 1,:]

        # Update pressure using the composite trapezoidal rule
        p_new = p_values[-1] + 0.5 * ( dpdz(p_values[-1], z_current, g, R_current, SST, c_p, H0) + dpdz(p_values[-1] + dpdz(p_values[-1], z_current, g, R_current, SST, c_p, H0) * dz[i], z_values[i], g, R_values[i], SST, c_p, H0)) * dz[i]
        p_values.append(p_new)

    return p_values

# %%
def increment_number_in_string(input_string):
    pattern = r'\d+'
    match = re.search(pattern, input_string)

    if match:
        number_str = match.group(0)
        incremented_number = str(int(number_str) + 1)

        result_string = re.sub(pattern, incremented_number, input_string, count=1)
        return result_string
    else:
        return input_string

# %%
def cut_grid(grid, indices, vars_to_renumber):
    new_grid = grid.load().isel(cell=indices.cell, vertex=indices.vertex, edge=indices.edge)
    for dim, idx in indices.coords.items():
        renumbering = np.full(grid.dims[dim], -2, dtype='int')
        renumbering[idx] = np.arange(len(idx))
        for name in vars_to_renumber[dim]:
            new_grid[name].data = renumbering[new_grid[name].data - 1] + 1
    return new_grid

# %%
def coriolis(reference_lat):   
    #siderial day in seconds: 86.164,0989 (source: Wikipedia)
    omega = 2 * np.pi / 86164.0989 #[1/s]
    return 2*omega*np.sin(np.deg2rad(reference_lat))

# %%
OCEAN_TYPES = ['atlantic']#, 'western_pacific', 'central_pacific', 'eastern_pacific', 'indian_ocean']
SEASONS = ['MAM', 'JJA', 'SON', 'DJF']
YEARS = ['2020', '2021', '2022']
DPP    = 'ngc2009'

# %% [raw]
# ZONAL_BINS = 50
# g_value = 9.787
# c_p = 1005
# V_c = 8
# GRID_SIZE = '2x2'
#
# for ocean_type in OCEAN_TYPES:
#     print(ocean_type)
#     for year in YEARS:
#         print(year)
#         for season in SEASONS:
#             #print(f"Processing {ocean_type}, {year}, {season}")
#             #            # New condition to skip certain seasons for the year 2020
#             #if year == '2020' and season in ['MAM', 'JJA', 'SON']:
#             #    continue  # Skip the current iteration
#
#             # Increment year if the season is DJF
#             if season == 'DJF':
#                 year = increment_number_in_string(year)
#             else:
#                 year = year
#
#             # Break condition for 'MAM' in the year 2022
#             if season == 'MAM' and year == '2022':
#                 break
#
#             print(f"Actually I am processing {ocean_type}, {year}, {season}")
#
#             # Get region coordinates
#             degrees_lower_box_bound, degrees_upper_box_bound, degrees_left_box_bound, degrees_right_box_bound = choose_region(ocean_type)
#             print("Fetching data for ", ocean_type, 'with:', choose_region(ocean_type))
#
#             # Filepaths for data
#             filepath = f"00_data/04_processed_datasets/{year}/09_{DPP}_WRAPUP_dataset_region_{degrees_lower_box_bound}_{degrees_upper_box_bound}_{degrees_left_box_bound}_{degrees_right_box_bound}_year_{year}_season_{season}.nc"
#             data = xr.open_dataset(filepath)
#
#             # Recovering the boolean in the valid and mask arrays
#             data = xr.merge([xr.where(data['valid'] == 1, True, False),
#                              xr.where(data['valid_oce'] == 1, True, False),
#                              xr.where(data['mask'] == 1, True, False),
#                              xr.where(data['mask_oce'] == 1, True, False),
#                              data.drop_vars({'valid', 'valid_oce', 'mask', 'mask_oce'})])
#
#             grid = xr.open_dataset(f"00_data/00_00_data/00_grid_info/new_grids/new_grid_{ocean_type}_{degrees_lower_box_bound}_{degrees_upper_box_bound}_{degrees_left_box_bound}_{degrees_right_box_bound}.nc")
#             ocean_grid = xr.open_dataset(f"00_data/00_00_data/00_grid_info/new_grids/new_oce_grid_{ocean_type}_{degrees_lower_box_bound}_{degrees_upper_box_bound}_{degrees_left_box_bound}_{degrees_right_box_bound}.nc")
#
#             cell_height = data.cell_height
#             mean_cell_height = cell_height.mean(dim='all_cells').rename({'cell_height_in_meter':'height'})
#
#             valid = data.valid.values
#             valid_oce = data.valid_oce.values
#             mask = data.mask.values
#             mask_oce = data.mask_oce.values
#
#             two_to_two_mask = np.where((grid.sel(cell=valid).sel(cell=mask).clat < np.deg2rad(2)) &
#                                        (grid.sel(cell=valid).sel(cell=mask).clat > np.deg2rad(-2)), True, False)
#
#             print("Just finished masking.")
#
#             seasons_df = pd.read_csv('top_of_ABL_values.csv', index_col=0)
#             top_of_ABL = seasons_df.loc[ocean_type, f'{year}-{season}']
#
#             print(f"Top of ABL is: {top_of_ABL}")
#
#             H0_value = mean_cell_height.isel(height=top_of_ABL).item()
#             rho_mean = data.rho_3d.isel(height=slice(0, top_of_ABL + 1))
#             prs_mean = data.pressure_fields.isel(height=slice(0, top_of_ABL + 1))
#             AirT_mean = data.ta.isel(height=slice(0, top_of_ABL + 1))
#             R_field = (prs_mean / (rho_mean * AirT_mean)).rename({'all_cells': 'cell'}).sel(cell=valid).sel(cell=mask)
#             SST = (data.to + 273.15).rename({'all_oce_cells': 'cell'}).sel(cell=valid_oce).sel(cell=mask_oce)
#
#             ICON_ABL_prs_field = data.pressure_fields.sel(all_cells=valid).sel(all_cells=mask).sel(height=top_of_ABL)
#             ICON_ABL_prs_mean = ICON_ABL_prs_field.mean(dim='all_cells')
#             ICON_ABL_prs = xr.full_like(ICON_ABL_prs_field, fill_value=ICON_ABL_prs_mean).rename({'all_cells': 'cell'})
#
#             z = mean_cell_height.isel(height=slice(0, top_of_ABL + 1))
#             z_extended = xr.concat([xr.DataArray([0], dims='height'), z], dim='height')
#
#             p_init = ICON_ABL_prs.mean()
#             dz = -np.diff(z_extended)
#
#             pressure_values = trapezoidal_rule(p_init, z, dz, g_value, R_field, SST, c_p, H0_value)
#
#             p0_RFM_by_hand = xr.DataArray(pressure_values[-1],
#                                           coords={'clon': ocean_grid.clon.sel(cell=valid_oce).sel(cell=mask_oce),
#                                                   'clat': ocean_grid.clat.sel(cell=valid_oce).sel(cell=mask_oce)},
#                                           dims=['cell'],
#                                           name="ICON_sfc_prs")
#
#             print(f"Finished p0_RFM_by_hand")
#
#             ## New Grid Indexing
#             orig_icon_grid = xr.open_dataset("/work/pd1295/ICON/grids/public/mpim/0015/icon_grid_0015_R02B09_G.nc")
#             orig_icon_oce_grid = xr.open_dataset("/work/pd1295/ICON/grids/public/mpim/0016/icon_grid_0016_R02B09_O.nc")
#
#             valid_masked_grid = grid.sel(cell=grid.cell[valid][mask].data)
#             valid_masked_ocean_grid = ocean_grid.sel(cell=ocean_grid.cell[valid_oce][mask_oce].data)
#
#             vars_to_renumber = {
#                 "cell": ["adjacent_cell_of_edge", "cells_of_vertex", "neighbor_cell_index", "cell_index"],
#                 "vertex": ["vertex_of_cell", "edge_vertices", "vertices_of_vertex"],
#                 "edge": ["edge_of_cell", "edges_of_vertex"],
#             }
#
#             selected_atm_indices = xr.Dataset({
#                 "cell": ("cell", valid_masked_grid.cell.data),
#                 "vertex": ("vertex", valid_masked_grid.vertex.data),
#                 "edge": ("edge", valid_masked_grid.edge.data),
#             })
#             selected_oce_indices = xr.Dataset({
#                 "cell": ("cell", valid_masked_ocean_grid.cell.data),
#                 "vertex": ("vertex", valid_masked_ocean_grid.vertex.data),
#                 "edge": ("edge", valid_masked_ocean_grid.edge.data),
#             })
#
#             new_ocean_grid = cut_grid(orig_icon_oce_grid, selected_oce_indices, vars_to_renumber)
#
#             ## Derivatives
#             p0_RFM_tapered_unmasked, dp0dx_RFM_tapered_unmasked, dp0dy_RFM_tapered_unmasked, second_time_valid_mask_oce = derivatives(new_ocean_grid, p0_RFM_by_hand)
#
#             p0_RFM_tapered = xr.DataArray(p0_RFM_tapered_unmasked, dims=['cell'], name="p0_RFM_tapered")
#             dp0dx_RFM_tapered = xr.DataArray(dp0dx_RFM_tapered_unmasked, dims=['cell'], name="dp0dx_RFM_tapered")
#             dp0dy_RFM_tapered = xr.DataArray(dp0dy_RFM_tapered_unmasked, dims=['cell'], name="dp0dy_RFM_tapered")
#
#             p0_icon_unmasked, dpdx_icon_unmasked, dpdy_icon_unmasked, _ = derivatives(grid, data.pressure_fields.sel(height=0))
#
#             p0_icon = xr.DataArray(p0_icon_unmasked[mask], dims=['cell'], name="p0_icon")
#             dpdx_icon = xr.DataArray(dpdx_icon_unmasked[mask], dims=['cell'], name="dpdx_icon")
#             dpdy_icon = xr.DataArray(dpdy_icon_unmasked[mask], dims=['cell'], name="dpdy_icon")
#
#             print(f"Finished Derivatives")
#
#             # Winds from SST derived Pressure Field
#             uu_sign = np.sign(data.uu.isel(height=0))
#             uu_square = (data.uu.isel(height=0) ** 2)
#             tauu = -data.surface_drag_u.isel(height=0)
#             C_d_cell = (np.abs(((tauu) / (uu_sign * uu_square)).rename({'all_cells': 'cell'})))
#             zonal_sfc_C_d_cell = (np.abs(((tauu) / (uu_sign * uu_square)).rename({'all_cells': 'cell'})))
#
#             vv_sign = np.sign(data.vv.isel(height=0))
#             vv_square = (data.vv.isel(height=0) ** 2)
#             tauv = -data.surface_drag_v.isel(height=0)
#             merid_sfc_C_d_cell = np.abs(((tauv) / (vv_sign * vv_square)).rename({'all_cells': 'cell'}))
#
#             H_0_height_limit = 21
#             H_0_ds = xr.DataArray(cell_height[:H_0_height_limit, :].mean(axis=1).values,
#                                   coords={'H_0': cell_height[:H_0_height_limit, :].mean(axis=1).values},
#                                   dims=["H_0"],
#                                   name="top_of_ABL")
#
#             mean_density_RFM_tapered = data.rho_3d.sel(height=0).mean(dim='all_cells')
#
#             f_coriolis = coriolis(np.rad2deg(ocean_grid.clat[valid_oce][mask_oce]))
#
#             epsilon_counter = 1
#             zonal_epsilon_Vc = (epsilon_counter * (zonal_sfc_C_d_cell * V_c / H_0_ds.H_0)).rename("Epsilon_at_H_0").sel(cell=valid).sel(cell=mask)
#             merid_epsilon_Vc = (epsilon_counter * (merid_sfc_C_d_cell * V_c / H_0_ds.H_0)).rename("Epsilon_at_H_0").sel(cell=valid).sel(cell=mask)
#
#             zonal_one_over_f_coriolis_2_epsilon_Vc_2 = 1 / ((f_coriolis ** 2) + (zonal_epsilon_Vc ** 2))
#             merid_one_over_f_coriolis_2_epsilon_Vc_2 = 1 / ((f_coriolis ** 2) + (merid_epsilon_Vc ** 2))
#
#             zonal_epsilon_Vc_mean_density_RFM_tapered = (zonal_epsilon_Vc / mean_density_RFM_tapered).sel(cell=second_time_valid_mask_oce)
#             merid_epsilon_Vc_mean_density_RFM_tapered = (merid_epsilon_Vc / mean_density_RFM_tapered).sel(cell=second_time_valid_mask_oce)
#
#             f_coriolis_mean_density_RFM_tapered = (f_coriolis / mean_density_RFM_tapered).sel(cell=second_time_valid_mask_oce)
#
#             p0_RFM_tapered_H0 = p0_RFM_tapered
#             dp0dx_RFM_tapered_H0 = dp0dx_RFM_tapered
#             dp0dy_RFM_tapered_H0 = dp0dy_RFM_tapered
#
#             uu_wind_RFM = zonal_one_over_f_coriolis_2_epsilon_Vc_2 * (
#                         - (zonal_epsilon_Vc_mean_density_RFM_tapered * dp0dx_RFM_tapered_H0) -
#                         (f_coriolis_mean_density_RFM_tapered * dp0dy_RFM_tapered_H0))
#             vv_wind_RFM = merid_one_over_f_coriolis_2_epsilon_Vc_2 * (
#                         (f_coriolis_mean_density_RFM_tapered * dp0dx_RFM_tapered_H0) -
#                         (merid_epsilon_Vc_mean_density_RFM_tapered * dp0dy_RFM_tapered_H0))
#
#             ## Get 10m Winds
#             variable = 'uas'
#             u10 = xr.open_dataset(f"{variable}/seasonal_means/{year}/{variable}_ngc2009_{degrees_lower_box_bound}_{degrees_upper_box_bound}_{degrees_left_box_bound}_{degrees_right_box_bound}_season_{season}.nc").squeeze('height_2')
#             variable = 'vas'
#             v10 = xr.open_dataset(f"{variable}/seasonal_means/{year}/{variable}_ngc2009_{degrees_lower_box_bound}_{degrees_upper_box_bound}_{degrees_left_box_bound}_{degrees_right_box_bound}_season_{season}.nc").squeeze('height_2')
#
#             A = u10.uas.sel(cell=valid).sel(cell=mask)
#             B = data.uu.sel(height=slice(0, top_of_ABL)).mean(dim='height').sel(all_cells=valid).sel(all_cells=mask)
#
#             u10_over_uABL_ratio = ((A.mean() / B.mean())) ** 2
#
#             C = v10.vas.sel(cell=valid).sel(cell=mask)
#             D = data.vv.sel(height=slice(0, top_of_ABL)).mean(dim='height').sel(all_cells=valid).sel(all_cells=mask)
#
#             v10_over_vABL_ratio = ((C.mean() / D.mean())) ** 2
#
#             windspeed = np.sqrt((u10.uas.sel(cell=valid).sel(cell=mask) ** 2) + (v10.vas.sel(cell=valid).sel(cell=mask) ** 2))
#
#             tauu = data.surface_drag_u.isel(height=0).rename({'all_cells': 'cell'}).sel(cell=valid).sel(cell=mask)
#             zonal_ABL_C_d_cell = (np.abs(((tauu) / (windspeed * u10.uas.sel(cell=valid).sel(cell=mask)))))
#
#             tauv = data.surface_drag_v.isel(height=0).rename({'all_cells': 'cell'}).sel(cell=valid).sel(cell=mask)
#             merid_ABL_C_d_cell = np.abs(((tauv) / (windspeed * v10.vas.sel(cell=valid).sel(cell=mask))))
#
#             one_over_rho = 1 / data.rho_3d.sel(height=top_of_ABL).rename({'all_cells': 'cell'}).sel(cell=valid).sel(cell=mask)
#             one_over_mean_rho_RFM_tapered = 1 / mean_density_RFM_tapered
#
#             # Get Alpha Values
#             alpha_values = pd.read_csv(f'00_data/09_00_data/09_alpha_values/alpha_values_for_{ocean_type}.csv', index_col=0)
#
#             alpha_u = alpha_values.loc[
#                 (alpha_values['Ocean_Type'] == ocean_type) &
#                 (alpha_values['Year'] == int(year)) &
#                 (alpha_values['Season'] == season) &
#                 (alpha_values['Grid_Size'] == GRID_SIZE),
#                 'alpha_u'
#             ].values[0]
#
#             alpha_v = alpha_values.loc[
#                 (alpha_values['Ocean_Type'] == ocean_type) &
#                 (alpha_values['Year'] == int(year)) &
#                 (alpha_values['Season'] == season) &
#                 (alpha_values['Grid_Size'] == GRID_SIZE),
#                 'alpha_v'
#             ].values[0]
#
#             print(f"{ocean_type}, {year}, {season}, {GRID_SIZE} \nalpha_u is: {alpha_u} \nalpha_v is: {alpha_v}")
#
#             # Zonal Means and Saving Files
#             ## ICON Original
#             ZM_uu_wind_icon_orig, lat_bins = zonal_mean_2nd_derivative(data.uu[0, valid][mask], grid.sel(cell=valid).sel(cell=mask), ZONAL_BINS)
#             ZM_vv_wind_icon_orig, lat_bins = zonal_mean_2nd_derivative(data.vv[0, valid][mask], grid.sel(cell=valid).sel(cell=mask), ZONAL_BINS)
#
#             np.save(f'00_data/07_fig_08_data/{ocean_type}/08_fig_ZM_uu_wind_icon_orig_{ocean_type}_{year}_{season}.npy', ZM_uu_wind_icon_orig)
#             np.save(f'00_data/07_fig_08_data/{ocean_type}/08_fig_ZM_vv_wind_icon_orig_{ocean_type}_{year}_{season}.npy', ZM_vv_wind_icon_orig)
#
#             ## Rayleigh Friction Model, Winkler et al., 2024, eq.(6)
#             ZM_uu_RFM, _ = zonal_mean_2nd_derivative(uu_wind_RFM.isel(H_0=top_of_ABL), new_ocean_grid.sel(cell=second_time_valid_mask_oce), ZONAL_BINS)
#             ZM_vv_RFM, _ = zonal_mean_2nd_derivative(vv_wind_RFM.isel(H_0=top_of_ABL), new_ocean_grid.sel(cell=second_time_valid_mask_oce), ZONAL_BINS)
#
#             np.save(f'00_data/07_fig_08_data/{ocean_type}/08_fig_ZM_uu_RFM_{ocean_type}_{year}_{season}.npy', ZM_uu_RFM)
#             np.save(f'00_data/07_fig_08_data/{ocean_type}/08_fig_ZM_vv_RFM_{ocean_type}_{year}_{season}.npy', ZM_vv_RFM)
#
#             ## Revised Model, Winkler et al., 2024, eq.(13)
#             uu_wind_revised = np.sign(-dp0dx_RFM_tapered_H0) * np.sqrt(np.abs((H_0_ds.isel(H_0=top_of_ABL) /
#                                     (zonal_ABL_C_d_cell.sel(cell=second_time_valid_mask_oce) * u10_over_uABL_ratio)) *
#                                     one_over_rho.sel(cell=second_time_valid_mask_oce) * (1 + alpha_u) * dp0dx_RFM_tapered_H0))
#
#             vv_wind_revised = np.sign(-dp0dy_RFM_tapered_H0) * np.sqrt(np.abs((H_0_ds.isel(H_0=top_of_ABL) /
#                                     (merid_ABL_C_d_cell.sel(cell=second_time_valid_mask_oce) * v10_over_vABL_ratio)) *
#                                     one_over_rho.sel(cell=second_time_valid_mask_oce) * (1 + alpha_v) * dp0dy_RFM_tapered_H0))
#
#             ZM_uu_wind_revised, _ = zonal_mean_2nd_derivative(uu_wind_revised, new_ocean_grid.sel(cell=second_time_valid_mask_oce), ZONAL_BINS)
#             ZM_vv_wind_revised, _ = zonal_mean_2nd_derivative(vv_wind_revised, new_ocean_grid.sel(cell=second_time_valid_mask_oce), ZONAL_BINS)
#
#             np.save(f'00_data/07_fig_08_data/{ocean_type}/08_fig_ZM_uu_wind_revised_{ocean_type}_{year}_{season}.npy', ZM_uu_wind_revised)
#             np.save(f'00_data/07_fig_08_data/{ocean_type}/08_fig_ZM_vv_wind_revised_{ocean_type}_{year}_{season}.npy', ZM_vv_wind_revised)
#
#             print(f"Safed all for {ocean_type}, {year}, {season}")

# %% [markdown]
# ! Until here the code has to be run 2 times.
#
# ! One time for OCEAN_TYPE = 'atlantic' and a second time for OCEAN_TYPE = 'western_pacific'

# %% [markdown]
# #
# #
# #

# %% [markdown]
# # Loading Data

# %%
ZONAL_BINS = 50

# %%
YEAR = '2020'

# %%
OCEAN_1 = 'western_pacific'
SEASON_1 = 'MAM'

ZM_uu_wind_icon_orig_wpcf = np.load(f'00_data/07_fig_08_data/{OCEAN_1}/08_fig_ZM_uu_wind_icon_orig_{OCEAN_1}_{YEAR}_{SEASON_1}.npy')
ZM_uu_RFM_wpcf            = np.load(f'00_data/07_fig_08_data/{OCEAN_1}/08_fig_ZM_uu_RFM_{OCEAN_1}_{YEAR}_{SEASON_1}.npy')
ZM_uu_wind_revised_wpcf   = np.load(f'00_data/07_fig_08_data/{OCEAN_1}/08_fig_ZM_uu_wind_revised_{OCEAN_1}_{YEAR}_{SEASON_1}.npy')

# %%
OCEAN_2 = 'atlantic'
SEASON_2 = 'SON'

ZM_vv_wind_icon_orig_atl = np.load(f'00_data/07_fig_08_data/{OCEAN_2}/08_fig_ZM_vv_wind_icon_orig_{OCEAN_2}_{YEAR}_{SEASON_2}.npy')
ZM_vv_RFM_atl            = np.load(f'00_data/07_fig_08_data/{OCEAN_2}/08_fig_ZM_vv_RFM_{OCEAN_2}_{YEAR}_{SEASON_2}.npy')
ZM_vv_wind_revised_atl   = np.load(f'00_data/07_fig_08_data/{OCEAN_2}/08_fig_ZM_vv_wind_revised_{OCEAN_2}_{YEAR}_{SEASON_2}.npy')

# %% [markdown]
# # Plotting

# %%
SIZE = 25
plt.rcParams['axes.labelsize']  = SIZE
plt.rcParams['legend.fontsize'] = SIZE
plt.rcParams['xtick.labelsize'] = SIZE
plt.rcParams['ytick.labelsize'] = SIZE
plt.rcParams['font.size']       = SIZE

# %%
fig = plt.figure(figsize=(20,10), facecolor='w', edgecolor='k')

G = gridspec.GridSpec(1,2)

y_lim_min = -10
y_lim_max = 10

ax1 = plt.subplot(G[0,0])

ax1.axhline(y = 0, color = 'grey', linestyle = '--', lw=1, zorder=3)
ax1.axvline(x = ZONAL_BINS/2, color = 'grey', linestyle = '--', lw=1, zorder=3)

ax1.plot(ZM_uu_wind_revised_wpcf, color='#FF7B9C', label=r'$t$', lw=3, linestyle='solid', zorder=2)
ax1.plot(ZM_uu_RFM_wpcf, color='darkorange', label=r'$u_{\mathrm{RFM}}$', linestyle='dashed', lw=3, zorder=2, alpha=1)

ax1.plot(ZM_uu_wind_icon_orig_wpcf, label=r'$u_{\mathrm{reference}}$', color='black', linestyle='dotted', zorder=2)

ax1.set_title('Zonal Wind Pattern', fontsize=SIZE+3, pad=30)
ax1.set_xlabel('Latitude / deg')
ax1.set_ylabel(r'Wind Speed / $\mathrm{ms}^{-1}$')
ax1.set_xlim((ZONAL_BINS/2)-(0.2*ZONAL_BINS),(ZONAL_BINS/2)+(0.2*ZONAL_BINS))
ax1.set_ylim(y_lim_min,y_lim_max)
ax1.set_xticks([(ZONAL_BINS/2)-(0.2*ZONAL_BINS), ZONAL_BINS/2, (ZONAL_BINS/2)+(0.2*ZONAL_BINS)])
ax1.set_xticklabels(['-2', '0', '2'])
ax1.set_yticks([-10,-5,0,5,10])
ax1.spines[['top', 'right']].set_visible(False)
ax1.spines[['left','bottom']].set_position(('outward',20))

ax1.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), fancybox=True, shadow=False, ncol=3)

################################################
y_lim_min = 0
y_lim_max = 30
################################################

ax2 = plt.subplot(G[0,1])

#ax2.axhline(y = 0, color = 'grey', linestyle = '--', lw=1, zorder=3)
ax2.axvline(x = ZONAL_BINS/2, color = 'grey', linestyle = '--', lw=1, zorder=3)

ax2.plot(ZM_vv_wind_revised_atl, color='#FF7B9C', label=r'$t$', lw=3, linestyle='solid', zorder=2)
ax2.plot(ZM_vv_RFM_atl, color='darkorange', label=r'$v_{\mathrm{RFM}}$', linestyle='dashed', lw=3, zorder=2, alpha=1)

ax2.plot(ZM_vv_wind_icon_orig_atl, label=r'$v_{\mathrm{reference}}$', color='black', linestyle='dotted', zorder=2)

ax2.set_title('Meridional Wind Pattern', fontsize=SIZE+3, pad=30)
ax2.set_xlabel('Latitude / deg')
#ax2.set_yticks([0, 5, 10, 15, 20, ])
#ax2.set_yticklabels([])
ax2.set_xlim((ZONAL_BINS/2)-(0.2*ZONAL_BINS),(ZONAL_BINS/2)+(0.2*ZONAL_BINS))
ax2.set_ylim(y_lim_min,y_lim_max)
ax2.set_xticks([(ZONAL_BINS/2)-(0.2*ZONAL_BINS), ZONAL_BINS/2, (ZONAL_BINS/2)+(0.2*ZONAL_BINS)])
ax2.set_xticklabels(['-2', '0', '2'])
ax2.spines[['top', 'right']].set_visible(False)
ax2.spines[['left','bottom']].set_position(('outward',20))

ax2.legend(loc='upper center', bbox_to_anchor=(0.5, -0.18), fancybox=True, shadow=False, ncol=3)

plt.tight_layout()

ax1.text(-0.22, 1.1, '(a)', fontsize=SIZE+8, transform=ax1.transAxes)
ax2.text(-0.12, 1.1, '(b)', fontsize=SIZE+8, transform=ax2.transAxes)

filename = f'fig_08.png'
filepath = '01_figs/'
plt.savefig(filepath + filename, facecolor='white', bbox_inches='tight', dpi=400)

plt.show()
